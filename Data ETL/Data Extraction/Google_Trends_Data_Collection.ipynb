# %% [markdown]
# # Tweepy

# %%
# ! pip install tweepy

# %%
import tweepy
import pandas as pd

# %%
auth = tweepy.OAuthHandler('Xq85TsKWMJlaLfkj1QWE51Cel', 'JgJvVyzB50JaVDsqvZmhS4S0Iv5kjTXDn6mcT11jMUvIyBPFNQ')
try:
    redirect_url = auth.get_authorization_url()
except tweepy.TweepError:
    print('Error! Failed to get request token.')

# %%
session.set('request_token', auth.request_token)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ed3b64ee2a6e> in <module>
# ----> 1 session.set('request_token', auth.request_token)
#
# NameError: name 'session' is not defined

# %% [markdown]
# # Crypto prices

# %%
# !pip install cryptocompare

# %%
import cryptocompare

# %%
cryptos = cryptocompare.get_coin_list(format = True)
len(cryptos)

# %%
cryptocompare.get_price('BTC', currency = 'USD')

# %%
response = requests.get('https://api.coindesk.com/v1/bpi/currentprice.json')
data = response.json()
print(json.dumps(data, indent = 2))

# %%
print(data['bpi']['USD']['rate'])

# %% [markdown]
# # PyTrends (Google trends)

# %%
# ! pip install pytrends

# %%
from pytrends.request import TrendReq

# %%
pytrends = TrendReq(hl='en-US', tz=360)

# %%
kw_list = ["bitcoin","btc"]
pytrends.build_payload(kw_list, cat = 0) 

data = pytrends.interest_over_time() 
data = data.reset_index() 


import plotly.express as px

fig = px.line(data, x="date", y=['bitcoin','btc'], title='Bitcoin Web Search Interest Over Time')
fig.show()
# Out:
# <div>                            <div id="c87d3fdb-8da9-4c5a-bcda-93d0625678e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c87d3fdb-8da9-4c5a-bcda-93d0625678e8")) {                    Plotly.newPlot(                        "c87d3fdb-8da9-4c5a-bcda-93d0625678e8",                        [{"hovertemplate":"variable=bitcoin<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"bitcoin","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"bitcoin","orientation":"v","showlegend":true,"type":"scatter","x":["2017-03-19T00:00:00","2017-03-26T00:00:00","2017-04-02T00:00:00","2017-04-09T00:00:00","2017-04-16T00:00:00","2017-04-23T00:00:00","2017-04-30T00:00:00","2017-05-07T00:00:00","2017-05-14T00:00:00","2017-
# ...

# %%
pytrends.get_historical_interest(kw_list, year_start=2014, month_start=1, day_start=1, hour_start=0, year_end=2022, month_end=2, day_end=25, hour_end=0, cat=0, geo='', gprop='', sleep=0)
# Out:
# /Users/milantoolsidas/opt/anaconda3/lib/python3.8/site-packages/pytrends/request.py:589: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/milantoolsidas/opt/anaconda3/lib/python3.8/site-packages/pytrends/request.py:589: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/milantoolsidas/opt/anaconda3/lib/python3.8/site-packages/pytrends/request.py:589: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# /Users/milantoolsidas/opt/anaconda3/lib/python3.8/site-packages/pytrends/request.py:589: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# ...

# %%
from pytrends.request import TrendReq
from pytrends import dailydata

df = dailydata.get_daily_data('bitcoin', 2014, 1, 2021, 12, geo = '')
# Out:
# bitcoin:2014-01-01 2014-01-31
# bitcoin:2014-02-01 2014-02-28
# bitcoin:2014-03-01 2014-03-31
# bitcoin:2014-04-01 2014-04-30
# bitcoin:2014-05-01 2014-05-31
# bitcoin:2014-06-01 2014-06-30
# bitcoin:2014-07-01 2014-07-31
# bitcoin:2014-08-01 2014-08-31
# bitcoin:2014-09-01 2014-09-30
# bitcoin:2014-10-01 2014-10-31
# bitcoin:2014-11-01 2014-11-30
# bitcoin:2014-12-01 2014-12-31
# bitcoin:2015-01-01 2015-01-31
# bitcoin:2015-02-01 2015-02-28
# bitcoin:2015-03-01 2015-03-31
# bitcoin:2015-04-01 2015-04-30
# bitcoin:2015-05-01 2015-05-31
# bitcoin:2015-06-01 2015-06-30
# bitcoin:2015-07-01 2015-07-31
# bitcoin:2015-08-01 2015-08-31
# bitcoin:2015-09-01 2015-09-30
# bitcoin:2015-10-01 2015-10-31
# bitcoin:2015-11-01 2015-11-30
# bitcoin:2015-12-01 2015-12-31
# bitcoin:2016-01-01 2016-01-31
# bitcoin:2016-02-01 2016-02-29
# bitcoin:2016-03-01 2016-03-31
# bitcoin:2016-04-01 2016-04-30
# bitcoin:2016-05-01 2016-05-31
# bitcoin:2016-06-01 2016-06-30
# bitcoin:2016-07-01 2016-07-31
# ...

# %%
df.to_csv('google_trends_bitcoin_2014.csv')

# %%
pd.read_csv('google_trends_bitcoin_2014.csv')
# Out:
#             date  bitcoin_unscaled  bitcoin_monthly isPartial  scale  bitcoin
# 0     2014-01-01                63              8.0     False   0.08     5.04
# 1     2014-01-02                68              8.0       NaN   0.08     5.44
# 2     2014-01-03                77              8.0       NaN   0.08     6.16
# 3     2014-01-04                63              8.0       NaN   0.08     5.04
# 4     2014-01-05                71              8.0       NaN   0.08     5.68
# ...          ...               ...              ...       ...    ...      ...
# 2917  2021-12-27                43             35.0       NaN   0.35    15.05
# 2918  2021-12-28                46             35.0       NaN   0.35    16.10
# 2919  2021-12-29                45             35.0       NaN   0.35    15.75
# 2920  2021-12-30                44             35.0       NaN   0.35    15.40
# 2921  2021-12-31                41             35.0       NaN   0.35    14.35
#
# [2922 rows x 6 columns]
